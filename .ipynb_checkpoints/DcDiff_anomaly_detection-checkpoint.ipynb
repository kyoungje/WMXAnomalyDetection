# %% [markdown]
# # LSTM Autoencoder Anomaly Detection
# ## Communication error detection through **WMX time-series data**
#
# **DC diff data gathered by the WMX ethercat master is used to detect anomalies in a time-series pattern.**
#
# In this notebook, we'll build an *LSTM Autoencoder representation learning model* . (See the following an example of autoencoder model.)
#
# <img src="https://lilianweng.github.io/posts/2018-08-12-vae/autoencoder-architecture.png" width="500">
#
# You can find **excellent reference projects** that help understand relevant concepts and techniques at the end of this notebook.

# %% [markdown]
# ## Preparation
# ### Install neccessary Python libraries
# Note that the Python environment where this notebook runs should already have **PyTorch** packages.
#
# (To install **PyTorch**, go to https://pytorch.org/get-started/locally/)

# %%
# !pip install scipy
# !pip install pandas
# !pip install seaborn
# !pip install -U scikit-learn
# !pip install -q -U watermark
# !pip install datasets
# !pip install huggingface-hub
# !pip install ipywidgets

# %% [markdown]
# ### Versions of the installed packages

# %%
# %reload_ext watermark
# %watermark -v -p numpy,pandas,torch,scipy
# Out:
# Python implementation: CPython
# Python version       : 3.11.10
# IPython version      : 8.29.0
#
# numpy : 2.0.1
# pandas: 2.2.3
# torch : 2.5.1
# scipy : 1.14.1

# %% [markdown]
# ### Import packages and initialize them

# %%
import torch

import copy
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split

from torch import nn, optim

import torch.nn.functional as F
from datasets import Dataset
from datasets import load_dataset
from huggingface_hub import login


# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]

sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))

rcParams['figure.figsize'] = 12, 8

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

torch.manual_seed(RANDOM_SEED)

# %% [markdown]
# ### Download the DC diff dataset from Hugging face and load the dataset
# Log in to the Hugging face before downloading
# (You may need a Hugging face account to login)

# %%
# Login to the Hugging face
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Load the dataset
dataset = load_dataset("Jake5/wmxdata") 

hg_df = pd.DataFrame(dataset['train'])

print(f"Total Values: {hg_df.shape[0]}")
print(hg_df.head())
# Out:
# Total Values: 100047
#                          Timestamp  DcDiffAvg
# 0 2024-11-01 04:13:46.454280+09:00     780472
# 1 2024-11-01 04:13:46.584383+09:00     783309
# 2 2024-11-01 04:13:46.693861+09:00     785026
# 3 2024-11-01 04:13:46.803610+09:00     786223
# 4 2024-11-01 04:13:46.913217+09:00     787620

# %% [markdown]
# ### Check if CUDA is available and use the CUDA avialble device

# %%
print(f"CUDA available={torch.cuda.is_available()}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# CUDA available=True

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Plot the current the first 1000 values of downloaded dataframe
hg_df['Timestamp'] = pd.to_datetime(hg_df['Timestamp'])

plt.plot(hg_df['Timestamp'].head(1000), hg_df['DcDiffAvg'].head(1000))

# %% [markdown]
# # LSTM Autoencoder

# %% [markdown]
# ## Data Preprocess the dataset (Normalization)

# %%
from copy import deepcopy as dc

def prepare_dataframe_for_lstm(df, n_steps):
    df = dc(df)

    df.set_index('Timestamp', inplace=True)

    for i in range(1, n_steps+1):
        df[f'DcDiffAvg(t-{i})'] = df['DcDiffAvg'].shift(i)

    df.dropna(inplace=True)

    return df

lookback = 10
shifted_df = prepare_dataframe_for_lstm(hg_df, lookback)
shifted_df
# Out:
#                                   DcDiffAvg  DcDiffAvg(t-1)  DcDiffAvg(t-2)  \
# Timestamp
# 2024-11-01 04:13:47.569243+09:00     697485        795808.0        794250.0
# 2024-11-01 04:13:47.678324+09:00     699122        697485.0        795808.0
# 2024-11-01 04:13:47.788463+09:00     700640        699122.0        697485.0
# 2024-11-01 04:13:47.897157+09:00     701797        700640.0        699122.0
# 2024-11-01 04:13:48.005174+09:00     703155        701797.0        700640.0
# ...                                     ...             ...             ...
# 2024-11-01 07:18:31.897394+09:00     708195        706358.0        704920.0
# 2024-11-01 07:18:32.006663+09:00     709593        708195.0        706358.0
# 2024-11-01 07:18:32.115753+09:00     711590        709593.0        708195.0
# 2024-11-01 07:18:32.225105+09:00     713108        711590.0        709593.0
# 2024-11-01 07:18:32.334622+09:00     714225        713108.0        711590.0
#
#                                   DcDiffAvg(t-3)  DcDiffAvg(t-4)  \
# Timestamp
# 2024-11-01 04:13:47.569243+09:00        792853.0        791095.0
# 2024-11-01 04:13:47.678324+09:00        794250.0        792853.0
# 2024-11-01 04:13:47.788463+09:00        795808.0        794250.0
# 2024-11-01 04:13:47.897157+09:00        697485.0        795808.0
# 2024-11-01 04:13:48.005174+09:00        699122.0        697485.0
# ...                                          ...             ...
# 2024-11-01 07:18:31.897394+09:00        703323.0        701805.0
# 2024-11-01 07:18:32.006663+09:00        704920.0        703323.0
# 2024-11-01 07:18:32.115753+09:00        706358.0        704920.0
# 2024-11-01 07:18:32.225105+09:00        708195.0        706358.0
# 2024-11-01 07:18:32.334622+09:00        709593.0        708195.0
#
#                                   DcDiffAvg(t-5)  DcDiffAvg(t-6)  \
# Timestamp
# 2024-11-01 04:13:47.569243+09:00        789378.0        787620.0
# 2024-11-01 04:13:47.678324+09:00        791095.0        789378.0
# 2024-11-01 04:13:47.788463+09:00        792853.0        791095.0
# 2024-11-01 04:13:47.897157+09:00        794250.0        792853.0
# 2024-11-01 04:13:48.005174+09:00        795808.0        794250.0
# ...                                          ...             ...
# 2024-11-01 07:18:31.897394+09:00        700289.0        698451.0
# 2024-11-01 07:18:32.006663+09:00        701805.0        700289.0
# 2024-11-01 07:18:32.115753+09:00        703323.0        701805.0
# 2024-11-01 07:18:32.225105+09:00        704920.0        703323.0
# 2024-11-01 07:18:32.334622+09:00        706358.0        704920.0
#
#                                   DcDiffAvg(t-7)  DcDiffAvg(t-8)  \
# Timestamp
# 2024-11-01 04:13:47.569243+09:00        786223.0        785026.0
# 2024-11-01 04:13:47.678324+09:00        787620.0        786223.0
# 2024-11-01 04:13:47.788463+09:00        789378.0        787620.0
# 2024-11-01 04:13:47.897157+09:00        791095.0        789378.0
# 2024-11-01 04:13:48.005174+09:00        792853.0        791095.0
# ...                                          ...             ...
# 2024-11-01 07:18:31.897394+09:00        797093.0        795176.0
# 2024-11-01 07:18:32.006663+09:00        698451.0        797093.0
# 2024-11-01 07:18:32.115753+09:00        700289.0        698451.0
# 2024-11-01 07:18:32.225105+09:00        701805.0        700289.0
# 2024-11-01 07:18:32.334622+09:00        703323.0        701805.0
#
#                                   DcDiffAvg(t-9)  DcDiffAvg(t-10)
# Timestamp
# 2024-11-01 04:13:47.569243+09:00        783309.0         780472.0
# 2024-11-01 04:13:47.678324+09:00        785026.0         783309.0
# 2024-11-01 04:13:47.788463+09:00        786223.0         785026.0
# 2024-11-01 04:13:47.897157+09:00        787620.0         786223.0
# 2024-11-01 04:13:48.005174+09:00        789378.0         787620.0
# ...                                          ...              ...
# 2024-11-01 07:18:31.897394+09:00        794138.0         792382.0
# 2024-11-01 07:18:32.006663+09:00        795176.0         794138.0
# 2024-11-01 07:18:32.115753+09:00        797093.0         795176.0
# 2024-11-01 07:18:32.225105+09:00        698451.0         797093.0
# 2024-11-01 07:18:32.334622+09:00        700289.0         698451.0
#
# [100037 rows x 11 columns]

# %%
shifted_df_as_np = shifted_df.to_numpy()

shifted_df_as_np
# Out:
# array([[697485., 795808., 794250., ..., 785026., 783309., 780472.],
#        [699122., 697485., 795808., ..., 786223., 785026., 783309.],
#        [700640., 699122., 697485., ..., 787620., 786223., 785026.],
#        ...,
#        [711590., 709593., 708195., ..., 698451., 797093., 795176.],
#        [713108., 711590., 709593., ..., 700289., 698451., 797093.],
#        [714225., 713108., 711590., ..., 701805., 700289., 698451.]])

# %%
shifted_df_as_np.shape
# Out:
# (100037, 11)

# %%
from sklearn.preprocessing import MinMaxScaler

# min~max = -1~1
scaler = MinMaxScaler(feature_range=(-1, 1))
shifted_df_as_np = scaler.fit_transform(shifted_df_as_np)

shifted_df_as_np
# Out:
# array([[-0.94893274,  0.89366766,  0.86447031, ...,  0.69160998,
#          0.65943292,  0.60626675],
#        [-0.91825491, -0.94893274,  0.89366766, ...,  0.71404209,
#          0.69160998,  0.65943292],
#        [-0.88980716, -0.91825491, -0.94893274, ...,  0.74022226,
#          0.71404209,  0.69160998],
#        ...,
#        [-0.68460111, -0.72202545, -0.74822436, ..., -0.93082963,
#          0.91774892,  0.8818238 ],
#        [-0.65615337, -0.68460111, -0.72202545, ..., -0.896385  ,
#         -0.93082963,  0.91774892],
#        [-0.63522048, -0.65615337, -0.68460111, ..., -0.86797474,
#         -0.896385  , -0.93082963]])

# %%
X = shifted_df_as_np[:, 1:]
y = shifted_df_as_np[:, 0]

# X is input values and y is target value
X.shape, y.shape
# Out:
# ((100037, 10), (100037,))

# %%
# Reverse data to make the recent one last
X = dc(np.flip(X, axis=1))
X
# Out:
# array([[ 0.60626675,  0.65943292,  0.69160998, ...,  0.83829014,
#          0.86447031,  0.89366766],
#        [ 0.65943292,  0.69160998,  0.71404209, ...,  0.86447031,
#          0.89366766, -0.94893274],
#        [ 0.69160998,  0.71404209,  0.74022226, ...,  0.89366766,
#         -0.94893274, -0.91825491],
#        ...,
#        [ 0.8818238 ,  0.91774892, -0.93082963, ..., -0.78265025,
#         -0.74822436, -0.72202545],
#        [ 0.91774892, -0.93082963, -0.896385  , ..., -0.74822436,
#         -0.72202545, -0.68460111],
#        [-0.93082963, -0.896385  , -0.86797474, ..., -0.72202545,
#         -0.68460111, -0.65615337]])

# %%
# Split data for train (95%) and test (5%)
split_index = int(len(X) * 0.95)

split_index
# Out:
# 95035

# %%
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((95035, 10), (5002, 10), (95035,), (5002,))

# %%
X_train = X_train.reshape((-1, lookback, 1))
X_test = X_test.reshape((-1, lookback, 1))

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((95035, 10, 1), (5002, 10, 1), (95035, 1), (5002, 1))

# %%
# Make tensors using the train and test data
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([95035, 10, 1]),
#  torch.Size([5002, 10, 1]),
#  torch.Size([95035, 1]),
#  torch.Size([5002, 1]))

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
train_dataset

# %%
from torch.utils.data import DataLoader

batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# See if the shape of batch is appropriate
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([32, 10, 1]) torch.Size([32, 1])

# %% [markdown]
# ## Building an LSTM Autoencoder

# %%
# Declare a class for LSTM neural network
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,
                            batch_first=True)

        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# Create the LSTM variable using input size = 1, hidden size = 4, number of stacked layers = 1 arguments
#model = LSTM(1, 4, 1)
model = LSTM(1, 128, 1)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 128, batch_first=True)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
def train_one_epoch(history):
    # Train mode
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    running_loss = 0.0
    train_losses = []

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_index % 100 == 99:  # print every 100 batches
            avg_loss_across_batches = running_loss / 100
            train_losses.append(avg_loss_across_batches)
            print('Batch {0}, Loss: {1:.3f}'.format(batch_index+1,
                                                    avg_loss_across_batches))
            running_loss = 0.0
    print()
    history['train'].append(np.mean(train_losses))

# %%
def validate_one_epoch(history):
    # Not train mode
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad():
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()

    avg_loss_across_batches = running_loss / len(test_loader)
    history['val'].append(avg_loss_across_batches)

    print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
    print('***************************************************')
    print()

# %% [markdown]
# # Training

# %%
learning_rate = 0.00001
num_epochs = 60
loss_function = nn.MSELoss()
#loss_function = nn.L1Loss(reduction='sum').to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
history = dict(train=[], val=[])

for epoch in range(num_epochs):
    train_one_epoch(history)
    validate_one_epoch(history)
# Out:
# Epoch: 1
# Batch 100, Loss: 0.025
# Batch 200, Loss: 0.017
# Batch 300, Loss: 0.022
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.018
# Batch 600, Loss: 0.025
# Batch 700, Loss: 0.022
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.027
# Batch 1000, Loss: 0.019
# Batch 1100, Loss: 0.016
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.018
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.023
# Batch 1700, Loss: 0.022
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.018
# Batch 2100, Loss: 0.024
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.029
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.018
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.019
# Batch 2800, Loss: 0.023
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.017
# Batch 200, Loss: 0.019
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.014
# Batch 500, Loss: 0.024
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.024
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.019
# Batch 1100, Loss: 0.020
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.023
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.019
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.024
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.024
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.023
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.020
# Batch 2700, Loss: 0.023
# Batch 2800, Loss: 0.017
# Batch 2900, Loss: 0.018
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.019
# Batch 500, Loss: 0.016
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.017
# Batch 900, Loss: 0.016
# Batch 1000, Loss: 0.024
# Batch 1100, Loss: 0.023
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.018
# Batch 1400, Loss: 0.016
# Batch 1500, Loss: 0.023
# Batch 1600, Loss: 0.027
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.025
# Batch 2000, Loss: 0.019
# Batch 2100, Loss: 0.023
# Batch 2200, Loss: 0.020
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.023
# Batch 2700, Loss: 0.022
# Batch 2800, Loss: 0.022
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.015
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.022
# Batch 500, Loss: 0.018
# Batch 600, Loss: 0.018
# Batch 700, Loss: 0.025
# Batch 800, Loss: 0.022
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.026
# Batch 1100, Loss: 0.020
# Batch 1200, Loss: 0.021
# Batch 1300, Loss: 0.014
# Batch 1400, Loss: 0.023
# Batch 1500, Loss: 0.022
# Batch 1600, Loss: 0.020
# Batch 1700, Loss: 0.018
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.014
# Batch 2000, Loss: 0.022
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.023
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.024
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.019
# Batch 2700, Loss: 0.018
# Batch 2800, Loss: 0.028
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.022
# Batch 200, Loss: 0.025
# Batch 300, Loss: 0.020
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.020
# Batch 800, Loss: 0.024
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.030
# Batch 1200, Loss: 0.016
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.017
# Batch 1600, Loss: 0.017
# Batch 1700, Loss: 0.025
# Batch 1800, Loss: 0.016
# Batch 1900, Loss: 0.024
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.023
# Batch 2200, Loss: 0.018
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.025
# Batch 2600, Loss: 0.019
# Batch 2700, Loss: 0.021
# Batch 2800, Loss: 0.024
# Batch 2900, Loss: 0.016
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.025
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.016
# Batch 800, Loss: 0.017
# Batch 900, Loss: 0.025
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.019
# Batch 1300, Loss: 0.016
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.022
# Batch 1600, Loss: 0.020
# Batch 1700, Loss: 0.017
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.016
# Batch 2000, Loss: 0.020
# Batch 2100, Loss: 0.025
# Batch 2200, Loss: 0.024
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.025
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.019
# Batch 2700, Loss: 0.018
# Batch 2800, Loss: 0.027
# Batch 2900, Loss: 0.024
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.024
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.017
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.016
# Batch 700, Loss: 0.015
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.023
# Batch 1000, Loss: 0.022
# Batch 1100, Loss: 0.019
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.023
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.022
# Batch 1600, Loss: 0.020
# Batch 1700, Loss: 0.025
# Batch 1800, Loss: 0.023
# Batch 1900, Loss: 0.022
# Batch 2000, Loss: 0.017
# Batch 2100, Loss: 0.020
# Batch 2200, Loss: 0.020
# Batch 2300, Loss: 0.023
# Batch 2400, Loss: 0.022
# Batch 2500, Loss: 0.023
# Batch 2600, Loss: 0.019
# Batch 2700, Loss: 0.024
# Batch 2800, Loss: 0.024
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.023
# Batch 400, Loss: 0.024
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.019
# Batch 700, Loss: 0.018
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.025
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.017
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.026
# Batch 1600, Loss: 0.018
# Batch 1700, Loss: 0.021
# Batch 1800, Loss: 0.018
# Batch 1900, Loss: 0.019
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.020
# Batch 2300, Loss: 0.025
# Batch 2400, Loss: 0.019
# Batch 2500, Loss: 0.018
# Batch 2600, Loss: 0.020
# Batch 2700, Loss: 0.024
# Batch 2800, Loss: 0.023
# Batch 2900, Loss: 0.023
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.015
# Batch 300, Loss: 0.024
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.017
# Batch 600, Loss: 0.021
# Batch 700, Loss: 0.018
# Batch 800, Loss: 0.021
# Batch 900, Loss: 0.025
# Batch 1000, Loss: 0.022
# Batch 1100, Loss: 0.019
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.017
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.019
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.031
# Batch 2000, Loss: 0.023
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.017
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.022
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.020
# Batch 300, Loss: 0.023
# Batch 400, Loss: 0.028
# Batch 500, Loss: 0.020
# Batch 600, Loss: 0.018
# Batch 700, Loss: 0.017
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.024
# Batch 1000, Loss: 0.025
# Batch 1100, Loss: 0.017
# Batch 1200, Loss: 0.026
# Batch 1300, Loss: 0.025
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.019
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.018
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.017
# Batch 2300, Loss: 0.019
# Batch 2400, Loss: 0.025
# Batch 2500, Loss: 0.020
# Batch 2600, Loss: 0.016
# Batch 2700, Loss: 0.021
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.023
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.018
# Batch 200, Loss: 0.023
# Batch 300, Loss: 0.022
# Batch 400, Loss: 0.017
# Batch 500, Loss: 0.016
# Batch 600, Loss: 0.018
# Batch 700, Loss: 0.018
# Batch 800, Loss: 0.023
# Batch 900, Loss: 0.025
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.018
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.018
# Batch 1400, Loss: 0.025
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.017
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.025
# Batch 2500, Loss: 0.023
# Batch 2600, Loss: 0.026
# Batch 2700, Loss: 0.019
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.024
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.025
# Batch 300, Loss: 0.022
# Batch 400, Loss: 0.018
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.024
# Batch 700, Loss: 0.018
# Batch 800, Loss: 0.026
# Batch 900, Loss: 0.025
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.019
# Batch 1200, Loss: 0.022
# Batch 1300, Loss: 0.019
# Batch 1400, Loss: 0.018
# Batch 1500, Loss: 0.018
# Batch 1600, Loss: 0.024
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.018
# Batch 2100, Loss: 0.023
# Batch 2200, Loss: 0.019
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.023
# Batch 2800, Loss: 0.019
# Batch 2900, Loss: 0.019
#
# Val Loss: 0.021
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.019
# Batch 200, Loss: 0.023
# Batch 300, Loss: 0.024
# Batch 400, Loss: 0.025
# Batch 500, Loss: 0.018
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.018
# Batch 800, Loss: 0.017
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.018
# Batch 1100, Loss: 0.024
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.015
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.025
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.027
# Batch 2000, Loss: 0.017
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.019
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.022
# Batch 2700, Loss: 0.023
# Batch 2800, Loss: 0.019
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.022
# Batch 200, Loss: 0.023
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.017
# Batch 500, Loss: 0.019
# Batch 600, Loss: 0.019
# Batch 700, Loss: 0.024
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.017
# Batch 1100, Loss: 0.023
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.023
# Batch 1400, Loss: 0.019
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.023
# Batch 1700, Loss: 0.014
# Batch 1800, Loss: 0.023
# Batch 1900, Loss: 0.022
# Batch 2000, Loss: 0.019
# Batch 2100, Loss: 0.018
# Batch 2200, Loss: 0.017
# Batch 2300, Loss: 0.023
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.017
# Batch 2600, Loss: 0.027
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.024
# Batch 2900, Loss: 0.022
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.018
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.018
# Batch 400, Loss: 0.018
# Batch 500, Loss: 0.018
# Batch 600, Loss: 0.017
# Batch 700, Loss: 0.019
# Batch 800, Loss: 0.017
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.016
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.022
# Batch 1700, Loss: 0.022
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.023
# Batch 2400, Loss: 0.024
# Batch 2500, Loss: 0.023
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.024
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.027
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.020
# Batch 300, Loss: 0.022
# Batch 400, Loss: 0.017
# Batch 500, Loss: 0.024
# Batch 600, Loss: 0.017
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.018
# Batch 900, Loss: 0.021
# Batch 1000, Loss: 0.018
# Batch 1100, Loss: 0.024
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.023
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.019
# Batch 1700, Loss: 0.018
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.017
# Batch 2000, Loss: 0.022
# Batch 2100, Loss: 0.025
# Batch 2200, Loss: 0.017
# Batch 2300, Loss: 0.022
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.020
# Batch 2700, Loss: 0.018
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.029
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.026
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.027
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.025
# Batch 700, Loss: 0.015
# Batch 800, Loss: 0.023
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.019
# Batch 1100, Loss: 0.019
# Batch 1200, Loss: 0.022
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.024
# Batch 1500, Loss: 0.018
# Batch 1600, Loss: 0.019
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.024
# Batch 2000, Loss: 0.020
# Batch 2100, Loss: 0.018
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.019
# Batch 2400, Loss: 0.019
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.024
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.023
# Batch 2900, Loss: 0.022
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.018
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.029
# Batch 400, Loss: 0.018
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.019
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.018
# Batch 900, Loss: 0.026
# Batch 1000, Loss: 0.018
# Batch 1100, Loss: 0.014
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.018
# Batch 1600, Loss: 0.020
# Batch 1700, Loss: 0.018
# Batch 1800, Loss: 0.019
# Batch 1900, Loss: 0.023
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.025
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.024
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.016
# Batch 400, Loss: 0.023
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.017
# Batch 800, Loss: 0.019
# Batch 900, Loss: 0.024
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.022
# Batch 1600, Loss: 0.019
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.024
# Batch 1900, Loss: 0.025
# Batch 2000, Loss: 0.023
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.020
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.021
# Batch 2500, Loss: 0.025
# Batch 2600, Loss: 0.017
# Batch 2700, Loss: 0.019
# Batch 2800, Loss: 0.017
# Batch 2900, Loss: 0.022
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.017
# Batch 200, Loss: 0.020
# Batch 300, Loss: 0.022
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.016
# Batch 600, Loss: 0.019
# Batch 700, Loss: 0.026
# Batch 800, Loss: 0.021
# Batch 900, Loss: 0.016
# Batch 1000, Loss: 0.019
# Batch 1100, Loss: 0.017
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.019
# Batch 1400, Loss: 0.019
# Batch 1500, Loss: 0.018
# Batch 1600, Loss: 0.018
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.024
# Batch 2000, Loss: 0.022
# Batch 2100, Loss: 0.023
# Batch 2200, Loss: 0.025
# Batch 2300, Loss: 0.027
# Batch 2400, Loss: 0.025
# Batch 2500, Loss: 0.022
# Batch 2600, Loss: 0.027
# Batch 2700, Loss: 0.025
# Batch 2800, Loss: 0.019
# Batch 2900, Loss: 0.016
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.028
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.024
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.023
# Batch 600, Loss: 0.017
# Batch 700, Loss: 0.020
# Batch 800, Loss: 0.016
# Batch 900, Loss: 0.021
# Batch 1000, Loss: 0.024
# Batch 1100, Loss: 0.018
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.024
# Batch 1400, Loss: 0.018
# Batch 1500, Loss: 0.026
# Batch 1600, Loss: 0.017
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.017
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.025
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.025
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.018
# Batch 2700, Loss: 0.019
# Batch 2800, Loss: 0.019
# Batch 2900, Loss: 0.019
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.025
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.024
# Batch 500, Loss: 0.025
# Batch 600, Loss: 0.019
# Batch 700, Loss: 0.022
# Batch 800, Loss: 0.016
# Batch 900, Loss: 0.015
# Batch 1000, Loss: 0.018
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.024
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.023
# Batch 1600, Loss: 0.024
# Batch 1700, Loss: 0.022
# Batch 1800, Loss: 0.015
# Batch 1900, Loss: 0.022
# Batch 2000, Loss: 0.016
# Batch 2100, Loss: 0.028
# Batch 2200, Loss: 0.019
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.019
# Batch 2500, Loss: 0.020
# Batch 2600, Loss: 0.017
# Batch 2700, Loss: 0.025
# Batch 2800, Loss: 0.022
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.029
# Batch 200, Loss: 0.019
# Batch 300, Loss: 0.024
# Batch 400, Loss: 0.017
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.014
# Batch 700, Loss: 0.018
# Batch 800, Loss: 0.022
# Batch 900, Loss: 0.024
# Batch 1000, Loss: 0.024
# Batch 1100, Loss: 0.017
# Batch 1200, Loss: 0.016
# Batch 1300, Loss: 0.019
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.017
# Batch 1600, Loss: 0.022
# Batch 1700, Loss: 0.021
# Batch 1800, Loss: 0.019
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.024
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.028
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.022
# Batch 2500, Loss: 0.022
# Batch 2600, Loss: 0.024
# Batch 2700, Loss: 0.023
# Batch 2800, Loss: 0.014
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.028
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.018
# Batch 400, Loss: 0.026
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.019
# Batch 800, Loss: 0.019
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.019
# Batch 1200, Loss: 0.019
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.019
# Batch 1500, Loss: 0.026
# Batch 1600, Loss: 0.017
# Batch 1700, Loss: 0.015
# Batch 1800, Loss: 0.017
# Batch 1900, Loss: 0.022
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.023
# Batch 2300, Loss: 0.024
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.026
# Batch 2700, Loss: 0.021
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.023
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.018
# Batch 400, Loss: 0.018
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.023
# Batch 700, Loss: 0.020
# Batch 800, Loss: 0.021
# Batch 900, Loss: 0.023
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.020
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.023
# Batch 1400, Loss: 0.017
# Batch 1500, Loss: 0.018
# Batch 1600, Loss: 0.018
# Batch 1700, Loss: 0.021
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.027
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.021
# Batch 2300, Loss: 0.023
# Batch 2400, Loss: 0.023
# Batch 2500, Loss: 0.020
# Batch 2600, Loss: 0.024
# Batch 2700, Loss: 0.024
# Batch 2800, Loss: 0.018
# Batch 2900, Loss: 0.015
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.023
# Batch 200, Loss: 0.020
# Batch 300, Loss: 0.022
# Batch 400, Loss: 0.016
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.017
# Batch 700, Loss: 0.022
# Batch 800, Loss: 0.019
# Batch 900, Loss: 0.024
# Batch 1000, Loss: 0.018
# Batch 1100, Loss: 0.018
# Batch 1200, Loss: 0.018
# Batch 1300, Loss: 0.029
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.017
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.022
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.025
# Batch 2000, Loss: 0.018
# Batch 2100, Loss: 0.020
# Batch 2200, Loss: 0.019
# Batch 2300, Loss: 0.022
# Batch 2400, Loss: 0.021
# Batch 2500, Loss: 0.025
# Batch 2600, Loss: 0.025
# Batch 2700, Loss: 0.024
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.019
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.019
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.016
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.019
# Batch 600, Loss: 0.025
# Batch 700, Loss: 0.019
# Batch 800, Loss: 0.022
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.024
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.021
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.023
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.017
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.023
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.016
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.022
# Batch 2600, Loss: 0.023
# Batch 2700, Loss: 0.024
# Batch 2800, Loss: 0.022
# Batch 2900, Loss: 0.022
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.025
# Batch 200, Loss: 0.020
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.018
# Batch 500, Loss: 0.023
# Batch 600, Loss: 0.023
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.023
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.021
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.018
# Batch 1500, Loss: 0.023
# Batch 1600, Loss: 0.019
# Batch 1700, Loss: 0.021
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.015
# Batch 2000, Loss: 0.024
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.018
# Batch 2300, Loss: 0.018
# Batch 2400, Loss: 0.016
# Batch 2500, Loss: 0.022
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.022
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.022
# Batch 200, Loss: 0.016
# Batch 300, Loss: 0.025
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.023
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.022
# Batch 800, Loss: 0.022
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.019
# Batch 1100, Loss: 0.021
# Batch 1200, Loss: 0.018
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.019
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.024
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.024
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.024
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.023
# Batch 2400, Loss: 0.019
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.019
# Batch 2700, Loss: 0.013
# Batch 2800, Loss: 0.019
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.018
# Batch 200, Loss: 0.019
# Batch 300, Loss: 0.018
# Batch 400, Loss: 0.022
# Batch 500, Loss: 0.020
# Batch 600, Loss: 0.025
# Batch 700, Loss: 0.026
# Batch 800, Loss: 0.022
# Batch 900, Loss: 0.027
# Batch 1000, Loss: 0.023
# Batch 1100, Loss: 0.016
# Batch 1200, Loss: 0.021
# Batch 1300, Loss: 0.017
# Batch 1400, Loss: 0.019
# Batch 1500, Loss: 0.024
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.024
# Batch 1800, Loss: 0.019
# Batch 1900, Loss: 0.022
# Batch 2000, Loss: 0.020
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.025
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.021
# Batch 2500, Loss: 0.020
# Batch 2600, Loss: 0.018
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.022
# Batch 2900, Loss: 0.019
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 31
# Batch 100, Loss: 0.025
# Batch 200, Loss: 0.019
# Batch 300, Loss: 0.013
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.021
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.018
# Batch 900, Loss: 0.017
# Batch 1000, Loss: 0.022
# Batch 1100, Loss: 0.023
# Batch 1200, Loss: 0.026
# Batch 1300, Loss: 0.024
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.019
# Batch 1600, Loss: 0.017
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.018
# Batch 1900, Loss: 0.029
# Batch 2000, Loss: 0.022
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.017
# Batch 2300, Loss: 0.023
# Batch 2400, Loss: 0.019
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.018
# Batch 2700, Loss: 0.023
# Batch 2800, Loss: 0.022
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 32
# Batch 100, Loss: 0.019
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.016
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.017
# Batch 900, Loss: 0.027
# Batch 1000, Loss: 0.024
# Batch 1100, Loss: 0.023
# Batch 1200, Loss: 0.016
# Batch 1300, Loss: 0.019
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.017
# Batch 1600, Loss: 0.023
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.023
# Batch 1900, Loss: 0.023
# Batch 2000, Loss: 0.024
# Batch 2100, Loss: 0.016
# Batch 2200, Loss: 0.019
# Batch 2300, Loss: 0.027
# Batch 2400, Loss: 0.022
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.018
# Batch 2700, Loss: 0.022
# Batch 2800, Loss: 0.017
# Batch 2900, Loss: 0.022
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 33
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.020
# Batch 300, Loss: 0.024
# Batch 400, Loss: 0.025
# Batch 500, Loss: 0.019
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.021
# Batch 800, Loss: 0.018
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.021
# Batch 1200, Loss: 0.018
# Batch 1300, Loss: 0.023
# Batch 1400, Loss: 0.023
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.020
# Batch 1700, Loss: 0.017
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.019
# Batch 2000, Loss: 0.023
# Batch 2100, Loss: 0.023
# Batch 2200, Loss: 0.018
# Batch 2300, Loss: 0.027
# Batch 2400, Loss: 0.015
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.025
# Batch 2700, Loss: 0.019
# Batch 2800, Loss: 0.017
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 34
# Batch 100, Loss: 0.019
# Batch 200, Loss: 0.019
# Batch 300, Loss: 0.025
# Batch 400, Loss: 0.024
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.022
# Batch 800, Loss: 0.016
# Batch 900, Loss: 0.015
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.023
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.023
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.019
# Batch 1600, Loss: 0.022
# Batch 1700, Loss: 0.018
# Batch 1800, Loss: 0.023
# Batch 1900, Loss: 0.024
# Batch 2000, Loss: 0.023
# Batch 2100, Loss: 0.020
# Batch 2200, Loss: 0.021
# Batch 2300, Loss: 0.019
# Batch 2400, Loss: 0.022
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.020
# Batch 2700, Loss: 0.016
# Batch 2800, Loss: 0.017
# Batch 2900, Loss: 0.027
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 35
# Batch 100, Loss: 0.019
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.014
# Batch 500, Loss: 0.023
# Batch 600, Loss: 0.018
# Batch 700, Loss: 0.020
# Batch 800, Loss: 0.021
# Batch 900, Loss: 0.020
# Batch 1000, Loss: 0.019
# Batch 1100, Loss: 0.029
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.022
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.018
# Batch 1600, Loss: 0.023
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.024
# Batch 2100, Loss: 0.018
# Batch 2200, Loss: 0.017
# Batch 2300, Loss: 0.018
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.019
# Batch 2700, Loss: 0.023
# Batch 2800, Loss: 0.023
# Batch 2900, Loss: 0.023
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 36
# Batch 100, Loss: 0.019
# Batch 200, Loss: 0.026
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.019
# Batch 500, Loss: 0.024
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.021
# Batch 800, Loss: 0.026
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.023
# Batch 1100, Loss: 0.023
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.024
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.018
# Batch 1700, Loss: 0.018
# Batch 1800, Loss: 0.018
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.017
# Batch 2100, Loss: 0.020
# Batch 2200, Loss: 0.019
# Batch 2300, Loss: 0.022
# Batch 2400, Loss: 0.025
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.017
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.024
# Batch 2900, Loss: 0.014
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 37
# Batch 100, Loss: 0.023
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.018
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.023
# Batch 600, Loss: 0.018
# Batch 700, Loss: 0.016
# Batch 800, Loss: 0.018
# Batch 900, Loss: 0.020
# Batch 1000, Loss: 0.017
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.025
# Batch 1300, Loss: 0.024
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.017
# Batch 1600, Loss: 0.023
# Batch 1700, Loss: 0.018
# Batch 1800, Loss: 0.016
# Batch 1900, Loss: 0.026
# Batch 2000, Loss: 0.015
# Batch 2100, Loss: 0.025
# Batch 2200, Loss: 0.024
# Batch 2300, Loss: 0.024
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.029
# Batch 2700, Loss: 0.021
# Batch 2800, Loss: 0.018
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 38
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.019
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.023
# Batch 500, Loss: 0.018
# Batch 600, Loss: 0.021
# Batch 700, Loss: 0.021
# Batch 800, Loss: 0.022
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.027
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.023
# Batch 1600, Loss: 0.019
# Batch 1700, Loss: 0.017
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.022
# Batch 2000, Loss: 0.022
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.021
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.027
# Batch 2500, Loss: 0.020
# Batch 2600, Loss: 0.025
# Batch 2700, Loss: 0.016
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.017
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 39
# Batch 100, Loss: 0.019
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.018
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.023
# Batch 600, Loss: 0.021
# Batch 700, Loss: 0.021
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.021
# Batch 1000, Loss: 0.019
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.017
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.024
# Batch 1700, Loss: 0.021
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.019
# Batch 2000, Loss: 0.028
# Batch 2100, Loss: 0.017
# Batch 2200, Loss: 0.023
# Batch 2300, Loss: 0.024
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.023
# Batch 2600, Loss: 0.020
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.025
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 40
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.025
# Batch 400, Loss: 0.015
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.019
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.018
# Batch 1200, Loss: 0.022
# Batch 1300, Loss: 0.019
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.020
# Batch 1700, Loss: 0.019
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.027
# Batch 2000, Loss: 0.023
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.020
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.023
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 41
# Batch 100, Loss: 0.023
# Batch 200, Loss: 0.024
# Batch 300, Loss: 0.023
# Batch 400, Loss: 0.022
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.019
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.017
# Batch 1100, Loss: 0.018
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.019
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.014
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.023
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.020
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.019
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.018
# Batch 2600, Loss: 0.025
# Batch 2700, Loss: 0.021
# Batch 2800, Loss: 0.024
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 42
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.027
# Batch 400, Loss: 0.017
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.019
# Batch 800, Loss: 0.019
# Batch 900, Loss: 0.024
# Batch 1000, Loss: 0.022
# Batch 1100, Loss: 0.015
# Batch 1200, Loss: 0.021
# Batch 1300, Loss: 0.018
# Batch 1400, Loss: 0.023
# Batch 1500, Loss: 0.025
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.026
# Batch 1800, Loss: 0.024
# Batch 1900, Loss: 0.017
# Batch 2000, Loss: 0.017
# Batch 2100, Loss: 0.022
# Batch 2200, Loss: 0.023
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.017
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 43
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.017
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.022
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.024
# Batch 700, Loss: 0.017
# Batch 800, Loss: 0.019
# Batch 900, Loss: 0.026
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.019
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.016
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.027
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.018
# Batch 1800, Loss: 0.024
# Batch 1900, Loss: 0.025
# Batch 2000, Loss: 0.016
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.020
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.020
# Batch 2600, Loss: 0.018
# Batch 2700, Loss: 0.024
# Batch 2800, Loss: 0.023
# Batch 2900, Loss: 0.022
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 44
# Batch 100, Loss: 0.025
# Batch 200, Loss: 0.024
# Batch 300, Loss: 0.016
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.023
# Batch 700, Loss: 0.020
# Batch 800, Loss: 0.018
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.017
# Batch 1100, Loss: 0.017
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.019
# Batch 1400, Loss: 0.019
# Batch 1500, Loss: 0.025
# Batch 1600, Loss: 0.019
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.019
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.017
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.021
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.023
# Batch 2600, Loss: 0.026
# Batch 2700, Loss: 0.025
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.023
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 45
# Batch 100, Loss: 0.019
# Batch 200, Loss: 0.023
# Batch 300, Loss: 0.024
# Batch 400, Loss: 0.018
# Batch 500, Loss: 0.018
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.025
# Batch 800, Loss: 0.021
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.018
# Batch 1100, Loss: 0.021
# Batch 1200, Loss: 0.024
# Batch 1300, Loss: 0.022
# Batch 1400, Loss: 0.028
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.022
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.018
# Batch 1900, Loss: 0.018
# Batch 2000, Loss: 0.015
# Batch 2100, Loss: 0.020
# Batch 2200, Loss: 0.027
# Batch 2300, Loss: 0.022
# Batch 2400, Loss: 0.021
# Batch 2500, Loss: 0.018
# Batch 2600, Loss: 0.019
# Batch 2700, Loss: 0.019
# Batch 2800, Loss: 0.017
# Batch 2900, Loss: 0.022
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 46
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.020
# Batch 400, Loss: 0.023
# Batch 500, Loss: 0.020
# Batch 600, Loss: 0.023
# Batch 700, Loss: 0.021
# Batch 800, Loss: 0.018
# Batch 900, Loss: 0.020
# Batch 1000, Loss: 0.022
# Batch 1100, Loss: 0.021
# Batch 1200, Loss: 0.017
# Batch 1300, Loss: 0.023
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.027
# Batch 1600, Loss: 0.023
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.025
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.024
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.018
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.026
# Batch 2600, Loss: 0.018
# Batch 2700, Loss: 0.018
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.017
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 47
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.022
# Batch 300, Loss: 0.027
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.017
# Batch 600, Loss: 0.027
# Batch 700, Loss: 0.017
# Batch 800, Loss: 0.020
# Batch 900, Loss: 0.020
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.023
# Batch 1200, Loss: 0.025
# Batch 1300, Loss: 0.019
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.017
# Batch 1600, Loss: 0.023
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.015
# Batch 1900, Loss: 0.017
# Batch 2000, Loss: 0.022
# Batch 2100, Loss: 0.018
# Batch 2200, Loss: 0.016
# Batch 2300, Loss: 0.028
# Batch 2400, Loss: 0.022
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.020
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.023
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 48
# Batch 100, Loss: 0.020
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.019
# Batch 700, Loss: 0.022
# Batch 800, Loss: 0.022
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.017
# Batch 1200, Loss: 0.026
# Batch 1300, Loss: 0.022
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.022
# Batch 1700, Loss: 0.017
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.022
# Batch 2000, Loss: 0.024
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.020
# Batch 2300, Loss: 0.018
# Batch 2400, Loss: 0.021
# Batch 2500, Loss: 0.023
# Batch 2600, Loss: 0.025
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.019
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 49
# Batch 100, Loss: 0.026
# Batch 200, Loss: 0.023
# Batch 300, Loss: 0.018
# Batch 400, Loss: 0.019
# Batch 500, Loss: 0.018
# Batch 600, Loss: 0.019
# Batch 700, Loss: 0.020
# Batch 800, Loss: 0.016
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.020
# Batch 1200, Loss: 0.019
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.022
# Batch 1700, Loss: 0.022
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.013
# Batch 2300, Loss: 0.026
# Batch 2400, Loss: 0.023
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.016
# Batch 2700, Loss: 0.024
# Batch 2800, Loss: 0.024
# Batch 2900, Loss: 0.024
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 50
# Batch 100, Loss: 0.016
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.019
# Batch 600, Loss: 0.021
# Batch 700, Loss: 0.022
# Batch 800, Loss: 0.026
# Batch 900, Loss: 0.021
# Batch 1000, Loss: 0.022
# Batch 1100, Loss: 0.019
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.026
# Batch 1400, Loss: 0.023
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.024
# Batch 1700, Loss: 0.025
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.024
# Batch 2000, Loss: 0.014
# Batch 2100, Loss: 0.017
# Batch 2200, Loss: 0.022
# Batch 2300, Loss: 0.023
# Batch 2400, Loss: 0.018
# Batch 2500, Loss: 0.020
# Batch 2600, Loss: 0.017
# Batch 2700, Loss: 0.022
# Batch 2800, Loss: 0.020
# Batch 2900, Loss: 0.018
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 51
# Batch 100, Loss: 0.024
# Batch 200, Loss: 0.023
# Batch 300, Loss: 0.023
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.026
# Batch 600, Loss: 0.018
# Batch 700, Loss: 0.021
# Batch 800, Loss: 0.021
# Batch 900, Loss: 0.017
# Batch 1000, Loss: 0.018
# Batch 1100, Loss: 0.022
# Batch 1200, Loss: 0.018
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.021
# Batch 1600, Loss: 0.021
# Batch 1700, Loss: 0.019
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.021
# Batch 2100, Loss: 0.025
# Batch 2200, Loss: 0.025
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.016
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.018
# Batch 2700, Loss: 0.018
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.018
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 52
# Batch 100, Loss: 0.027
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.016
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.025
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.020
# Batch 800, Loss: 0.026
# Batch 900, Loss: 0.023
# Batch 1000, Loss: 0.024
# Batch 1100, Loss: 0.020
# Batch 1200, Loss: 0.025
# Batch 1300, Loss: 0.025
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.022
# Batch 1600, Loss: 0.015
# Batch 1700, Loss: 0.017
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.023
# Batch 2000, Loss: 0.019
# Batch 2100, Loss: 0.020
# Batch 2200, Loss: 0.017
# Batch 2300, Loss: 0.022
# Batch 2400, Loss: 0.019
# Batch 2500, Loss: 0.018
# Batch 2600, Loss: 0.017
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.024
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 53
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.016
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.016
# Batch 500, Loss: 0.021
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.019
# Batch 800, Loss: 0.019
# Batch 900, Loss: 0.022
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.024
# Batch 1200, Loss: 0.019
# Batch 1300, Loss: 0.018
# Batch 1400, Loss: 0.026
# Batch 1500, Loss: 0.022
# Batch 1600, Loss: 0.018
# Batch 1700, Loss: 0.019
# Batch 1800, Loss: 0.021
# Batch 1900, Loss: 0.027
# Batch 2000, Loss: 0.023
# Batch 2100, Loss: 0.024
# Batch 2200, Loss: 0.020
# Batch 2300, Loss: 0.019
# Batch 2400, Loss: 0.023
# Batch 2500, Loss: 0.018
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.022
# Batch 2800, Loss: 0.024
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 54
# Batch 100, Loss: 0.018
# Batch 200, Loss: 0.018
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.026
# Batch 600, Loss: 0.022
# Batch 700, Loss: 0.016
# Batch 800, Loss: 0.026
# Batch 900, Loss: 0.025
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.018
# Batch 1200, Loss: 0.022
# Batch 1300, Loss: 0.018
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.024
# Batch 1600, Loss: 0.029
# Batch 1700, Loss: 0.024
# Batch 1800, Loss: 0.017
# Batch 1900, Loss: 0.018
# Batch 2000, Loss: 0.019
# Batch 2100, Loss: 0.018
# Batch 2200, Loss: 0.019
# Batch 2300, Loss: 0.024
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.018
# Batch 2600, Loss: 0.022
# Batch 2700, Loss: 0.021
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.019
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 55
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.020
# Batch 300, Loss: 0.024
# Batch 400, Loss: 0.019
# Batch 500, Loss: 0.020
# Batch 600, Loss: 0.018
# Batch 700, Loss: 0.015
# Batch 800, Loss: 0.025
# Batch 900, Loss: 0.019
# Batch 1000, Loss: 0.026
# Batch 1100, Loss: 0.019
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.022
# Batch 1400, Loss: 0.020
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.018
# Batch 1700, Loss: 0.026
# Batch 1800, Loss: 0.020
# Batch 1900, Loss: 0.023
# Batch 2000, Loss: 0.019
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.017
# Batch 2300, Loss: 0.025
# Batch 2400, Loss: 0.021
# Batch 2500, Loss: 0.021
# Batch 2600, Loss: 0.022
# Batch 2700, Loss: 0.023
# Batch 2800, Loss: 0.023
# Batch 2900, Loss: 0.016
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 56
# Batch 100, Loss: 0.024
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.021
# Batch 400, Loss: 0.023
# Batch 500, Loss: 0.018
# Batch 600, Loss: 0.025
# Batch 700, Loss: 0.018
# Batch 800, Loss: 0.018
# Batch 900, Loss: 0.026
# Batch 1000, Loss: 0.023
# Batch 1100, Loss: 0.021
# Batch 1200, Loss: 0.020
# Batch 1300, Loss: 0.020
# Batch 1400, Loss: 0.021
# Batch 1500, Loss: 0.020
# Batch 1600, Loss: 0.022
# Batch 1700, Loss: 0.016
# Batch 1800, Loss: 0.024
# Batch 1900, Loss: 0.022
# Batch 2000, Loss: 0.018
# Batch 2100, Loss: 0.023
# Batch 2200, Loss: 0.019
# Batch 2300, Loss: 0.025
# Batch 2400, Loss: 0.020
# Batch 2500, Loss: 0.020
# Batch 2600, Loss: 0.017
# Batch 2700, Loss: 0.022
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.019
#
# Val Loss: 0.020
# ***************************************************
#
# Epoch: 57
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.020
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.022
# Batch 600, Loss: 0.018
# Batch 700, Loss: 0.026
# Batch 800, Loss: 0.022
# Batch 900, Loss: 0.020
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.017
# Batch 1200, Loss: 0.022
# Batch 1300, Loss: 0.026
# Batch 1400, Loss: 0.019
# Batch 1500, Loss: 0.017
# Batch 1600, Loss: 0.020
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.022
# Batch 1900, Loss: 0.021
# Batch 2000, Loss: 0.022
# Batch 2100, Loss: 0.019
# Batch 2200, Loss: 0.015
# Batch 2300, Loss: 0.020
# Batch 2400, Loss: 0.026
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.020
# Batch 2700, Loss: 0.026
# Batch 2800, Loss: 0.022
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 58
# Batch 100, Loss: 0.021
# Batch 200, Loss: 0.024
# Batch 300, Loss: 0.019
# Batch 400, Loss: 0.020
# Batch 500, Loss: 0.025
# Batch 600, Loss: 0.024
# Batch 700, Loss: 0.019
# Batch 800, Loss: 0.021
# Batch 900, Loss: 0.016
# Batch 1000, Loss: 0.021
# Batch 1100, Loss: 0.025
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.027
# Batch 1400, Loss: 0.017
# Batch 1500, Loss: 0.019
# Batch 1600, Loss: 0.025
# Batch 1700, Loss: 0.018
# Batch 1800, Loss: 0.018
# Batch 1900, Loss: 0.023
# Batch 2000, Loss: 0.015
# Batch 2100, Loss: 0.023
# Batch 2200, Loss: 0.017
# Batch 2300, Loss: 0.019
# Batch 2400, Loss: 0.023
# Batch 2500, Loss: 0.019
# Batch 2600, Loss: 0.024
# Batch 2700, Loss: 0.017
# Batch 2800, Loss: 0.018
# Batch 2900, Loss: 0.020
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 59
# Batch 100, Loss: 0.015
# Batch 200, Loss: 0.015
# Batch 300, Loss: 0.016
# Batch 400, Loss: 0.019
# Batch 500, Loss: 0.027
# Batch 600, Loss: 0.021
# Batch 700, Loss: 0.023
# Batch 800, Loss: 0.026
# Batch 900, Loss: 0.021
# Batch 1000, Loss: 0.016
# Batch 1100, Loss: 0.023
# Batch 1200, Loss: 0.019
# Batch 1300, Loss: 0.021
# Batch 1400, Loss: 0.022
# Batch 1500, Loss: 0.023
# Batch 1600, Loss: 0.020
# Batch 1700, Loss: 0.020
# Batch 1800, Loss: 0.017
# Batch 1900, Loss: 0.015
# Batch 2000, Loss: 0.022
# Batch 2100, Loss: 0.021
# Batch 2200, Loss: 0.026
# Batch 2300, Loss: 0.021
# Batch 2400, Loss: 0.025
# Batch 2500, Loss: 0.024
# Batch 2600, Loss: 0.021
# Batch 2700, Loss: 0.020
# Batch 2800, Loss: 0.021
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.019
# ***************************************************
#
# Epoch: 60
# Batch 100, Loss: 0.022
# Batch 200, Loss: 0.021
# Batch 300, Loss: 0.025
# Batch 400, Loss: 0.021
# Batch 500, Loss: 0.016
# Batch 600, Loss: 0.020
# Batch 700, Loss: 0.020
# Batch 800, Loss: 0.021
# Batch 900, Loss: 0.023
# Batch 1000, Loss: 0.020
# Batch 1100, Loss: 0.026
# Batch 1200, Loss: 0.023
# Batch 1300, Loss: 0.015
# Batch 1400, Loss: 0.019
# Batch 1500, Loss: 0.027
# Batch 1600, Loss: 0.022
# Batch 1700, Loss: 0.023
# Batch 1800, Loss: 0.016
# Batch 1900, Loss: 0.020
# Batch 2000, Loss: 0.019
# Batch 2100, Loss: 0.020
# Batch 2200, Loss: 0.026
# Batch 2300, Loss: 0.018
# Batch 2400, Loss: 0.016
# Batch 2500, Loss: 0.016
# Batch 2600, Loss: 0.022
# Batch 2700, Loss: 0.017
# Batch 2800, Loss: 0.022
# Batch 2900, Loss: 0.021
#
# Val Loss: 0.020
# ***************************************************

# %% [markdown]
# ## Plot actual and predicted values

# %%
with torch.no_grad():
    predicted = model(X_train.to(device)).to('cpu').numpy()

plt.plot(y_train[:2000], label='Actual DcDiffAvg')
plt.plot(predicted[:2000], label='Predicted DcDiffAvg')
plt.xlabel('Timestamp')
plt.ylabel('DcDiffAvg')
plt.legend()
plt.show()

# %% [markdown]
# ## Loss over training epochs

# %%
# Plot loss function
ax = plt.figure().gca()

ax.plot(history['train'])
ax.plot(history['val'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.title('Loss over training epochs')
plt.show();

# %% [markdown]
# ## Model Assessment
#
# The training loss (blue line) shows a steady and stable learning curve, starting at around 0.021 and gradually decreasing to approximately 0.0207 by the end of training.
#
# This consistent downward trend indicates that the model is learning effectively and improving its reconstruction capabilities on the training data.
#
# Compared to the previous model trained with the higher learning_rate(*0.0001*), the validation loss (yellow line) exhibits several notable characteristics:
#
# - Reduced amplitude in fluctuations (ranging between 0.019-0.0205) compared to the previous model's wider range
#
# - More controlled spikes without the extreme peaks seen in the original model
#
# - Consistently lower values than the training loss, indicating good generalization

# %% [markdown]
# ## Saving the model

# %%
MODEL_PATH = 'model.pth'

torch.save(model, MODEL_PATH)

# %% [markdown]
# ## Loading the model (when using the model without training)

# %%
model = torch.load('model.pth')

model = model.to(device)
# Out:
# C:\Users\JakeKyoungjeOh\AppData\Local\Temp\ipykernel_14084\2167487449.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load('model.pth')

# %% [markdown]
# ## Choosing a threashold

# %%
def predict(model, dataset):
  predictions, losses = [], []
  with torch.no_grad():
    model = model.eval()
    for batch_index, batch in enumerate(dataset):
      x_batch, y_batch = batch[0].to(device), batch[1].to(device)

      output = model(x_batch)
      loss = loss_function(output, y_batch)

      predictions.append(output.cpu().numpy().flatten())
      losses.append(loss.item())
  return predictions, losses

# %%
_, losses = predict(model, train_loader)
sns.histplot(losses, bins=50, kde=True).set_title("Loss histogram of train data")
# Out:
# Text(0.5, 1.0, 'Loss histogram of train data')

# %%
# Choose the threashold using the loss histogram
THRESHOLD = 0.1

# %% [markdown]
# # Evaluation
#
# Using the threshold, we can turn the problem into a simple *binary classification task*:
#
# - If the reconstruction loss is below the threshold, classify it as a **normal data**
#
# - Alternatively, if the loss is higher than the threshold, classify it as an **anomaly**

# %% [markdown]
# ## Normal DC Diff

# %%
redictions, pred_losses = predict(model, test_loader)
sns.histplot(pred_losses, bins=50, kde=True).set_title("Loss histogram of test data")
# Out:
# Text(0.5, 1.0, 'Loss histogram of test data')

# %% [markdown]
# ## Anomalies

# %% [markdown]
# ## Looking at Examples

# %% [markdown]
# ## Remaining Considerations
#
# - Some validation volatility still exists, though significantly reduced
#
# - The training loss could potentially benefit from further fine-tuning to achieve even smoother convergence
#
# - The model might benefit from a longer training period to see if the trend continues to improve

# %% [markdown]
# # References
#
# - [Time Series Anomaly Detection Tutorial with PyTorch in Python | LSTM Autoencoder for ECG Data](https://www.youtube.com/watch?v=qN3n0TM4Jno)
# - [Amazon Stock Forecasting in PyTorch with LSTM Neural Network (Time Series Forecasting) | Tutorial 3](https://www.youtube.com/watch?v=q_HS4s1L8UI&t=5s)
# - [\[NHN Cloud make IT 2023\] 시계열 데이터 속에 숨어있는 이상 징후를 찾는 딥 러닝 기술](https://www.youtube.com/watch?v=bg2e60IZ40Q)
